# %%
from Module import Module as md
source='./images/'
output='./out/'
md.spectrum_compare(source,output,'row.png')
# Out:
# array([[255, 255, 255, ..., 180, 176, 192],
#        [255, 255, 255, ...,  60,  56, 110],
#        [255, 255, 255, ...,  65,  75,  92],
#        ...,
#        [255, 255, 255, ..., 116, 128, 104],
#        [255, 255, 255, ...,  98, 134, 104],
#        [255, 255, 255, ..., 218, 128, 224]], dtype=uint8)

# %%
md.spectrum_compare(source,output,'row1.png')
# Out:
# C:\Users\java_lee\Documents\GitHub\De-skew-scanned-pdf\Module.py:56: RuntimeWarning: divide by zero encountered in log
#   data = 20*np.log(np.abs(fshift)) # 傅里叶变换得到的复数取模 取对数 得到频域能量谱
# array([[255, 255, 255, ..., 255, 146, 160],
#        [255, 255, 255, ..., 255, 146, 160],
#        [255, 255, 255, ..., 255, 146, 160],
#        ...,
#        [255, 255, 255, ..., 255, 146, 160],
#        [255, 255, 255, ..., 255, 146, 160],
#        [255, 255, 255, ..., 255, 146, 160]], dtype=uint8)

# %%
md.spectrum_compare(source,output,'row2.png')
# Out:
# array([[255, 255, 255, ...,  28, 180,  73],
#        [255, 255, 255, ...,  27,  20, 128],
#        [255, 255, 255, ...,  10,  24,  17],
#        ...,
#        [255, 255, 255, ...,  21,  50,  16],
#        [255, 255, 255, ..., 113,  25,  64],
#        [255, 255, 255, ...,  53, 208,  35]], dtype=uint8)

# %%
md.spectrum_compare(source,output,'row3.png')
# Out:
# array([[255, 255, 255, ..., 191, 218,  84],
#        [255, 255, 255, ..., 221, 244, 254],
#        [255, 255, 255, ...,  13, 112, 227],
#        ...,
#        [255, 255, 255, ...,  70, 229, 215],
#        [255, 255, 255, ..., 124,  75, 235],
#        [255, 255, 255, ..., 208, 100,  75]], dtype=uint8)
